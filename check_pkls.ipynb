# %% [markdown]
# # Look in pkl to see which epoch perfomed the best

# %%
PREFIX = "/net/talisker/home/benos/mae117/collaborations/atac_convolutions/data/outputs"
FN="stats-tmp.pkl"

# %%
import pickle

# %%
with open(f"{PREFIX}/{FN}", "rb") as pkl:                                                                                      
    stats = pickle.load(pkl)

# %%
stats.keys()
# Out:
# dict_keys(['train_average_loss', 'validation_average_loss', 'test_average_loss', 'completed', 'lr'])

# %%
[print(i,j) for i, j in enumerate(stats['validation_average_loss'])]
# Out:
# 0 0.41496983
# 1 0.41634598
# 2 0.30380395
# 3 0.28800687
# 4 0.2812706
# 5 0.27893037
# 6 0.2769932
# 7 0.27523157
# 8 0.27211863
# 9 0.2652369
# 10 0.25313753
# 11 0.2462995
# 12 0.2411297
# 13 0.23893878
# 14 0.24168235
# 15 0.24533199
# 16 0.24988556
# 17 0.2559162
# 18 0.25749668
# 19 0.26296338
# 20 0.2669049
# 21 0.26728943
# 22 0.27209827
# 23 0.27169126
# 24 0.27554718
# 25 0.27797943
# 26 0.2812991
# 27 0.28357252
# 28 0.285342
# 29 0.28630042
# 30 0.2888506
# 31 0.29109117
# 32 0.29328495
# 33 0.2942717
# 34 0.2949438
# 35 0.29613683
# 36 0.29864928
# 37 0.29891825
# 38 0.29950243
# 39 0.29941604
# 40 0.29960176
# 41 0.29980347
# 42 0.30048925
# 43 0.30041844
# 44 0.30032578
# 45 0.30034563
# 46 0.30167955
# 47 0.3011667
# 48 0.3007554
# 49 0.3010847
# 50 0.3016329
# 51 0.30143994
# 52 0.30134824
# 53 0.30159423
# 54 0.300809
# 55 0.30131572
# 56 0.3011458
# 57 0.30101636
# 58 0.30080426
# 59 0.30089658
# 60 0.30136287
# 61 0.30149993
# 62 0.3012653
# 63 0.30090025
# ...
